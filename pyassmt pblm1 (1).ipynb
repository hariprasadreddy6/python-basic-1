# %% [markdown]
# #solution to problem 1

# %%
weight = input ("Enter your weight in kgs ")
height_unit = input (' what is your preferred unit of height "F" of feet and "M" for meter')

if height_unit == "F":
    print("I am in the F block. TODO")
else:
    print("I am in the M block.TODO")
# Out:
# Enter your weight in kgs 72
#  what is your preferred unit of height "F" of feet and "M" for meterF
# I am in the F block. TODO

# %%
weight = input("Enter your weight in kgs ")
height_unit = input(' what is your preferred unit of height "F" of feet and "M" for meter')

if height_unit == "F":
    feet =input("please enter both feet and inches. Now enter feet")
    inches =input("Now enter inches")
else:
    meters = input ("please enter your height in meters ")
# Out:
# Enter your weight in kgs 72
#  what is your preferred unit of height "F" of feet and "M" for meterF
# please enter both feet and inches. Now enter feet6
# Now enter inches0

# %%
weight = input("Enter your weight in kgs ")
height_unit = input(' what is your preferred unit of height "F" of feet and "M" for meter')

if height_unit == "F":
    feet =input("please enter both feet and inches. Now enter feet")
    inches =input("Now enter inches")
    metera = (feet + inches/12) * 0.3048
else:
    meters = input ("please enter your height in meters ")

height = meters
# Out:
# Enter your weight in kgs 72
#  what is your preferred unit of height "F" of feet and "M" for meterM
# please enter your height in meters 1.82

# %%
def input_single_integer(prompt):
    ret = int(input(prompt))
    return ret

# %%
weight = input("Enter your weight in kgs ")
height_unit = input(' what is your preferred unit of height "F" of feet and "M" for meter')

if height_unit == "F":
    feet =input_single_integer("please enter both feet and inches. Now enter feet")
    inches =input_single_integer("Now enter inches")
    meters = (feet + inches/12) * 0.3048
else:
    meters = input ("please enter your height in meters ")

height = meters
# Out:
# Enter your weight in kgs 72
#  what is your preferred unit of height "F" of feet and "M" for meterF
# please enter both feet and inches. Now enter feet6
# Now enter inches0

# %%
print(meters)
# Out:
# 1.82

# %%
def factorial(n):
    product = 1
    for i in range(n):
        #print(i,product)
        product *= (i + 1)
    return product

# %%
print (factorial(3))
# Out:
# 6

# %%
def factorial_recursive(n):
    if n > 1:
        return n * factorial_recursive(n-1)
    else:
        return 1

# %%
print(factorial_recursive(3))
# Out:
# 6

# %%
def compute_ratio(x, n):
    ratio = x**n / factorial(n)
    return ratio

# %%
compute_ratio(2,3)
# Out:
# 1.3333333333333333

# %%
def compute_sum(x,N):
    sum =1
    for i in range(N):
        sum += compute_ratio(x, i+1)
    return sum

# %%
print(compute_sum(2, 3))
# Out:
# 6.333333333333333

# %%
def compute_sum_epsilon(x, epsilon):
    sum = 1
    var = epsilon
    i = 1
    while var >= epsilon:
        var = compute_ratio(x, i)
        sum += var
        i += 1
    return sum

# %%
print(compute_sum_epsilon(2, 0.01))
# Out:
# 7.387301587301587

# %%
p = 2.1
q = 1.3

v1 = compute_sum(p,100) * compute_sum(q, 100)
v2 = compute_sum(p + q, 100)

print(v1,v2 - v1)
# Out:
# 29.964100047397018 1.0658141036401503e-14

# %%
for i in range(10):
    print(i,compute_sum(i, 100))
# Out:
# 0 1.0
# 1 2.7182818284590455
# 2 7.389056098930649
# 3 20.08553692318766
# 4 54.598150033144265
# 5 148.41315910257657
# 6 403.4287934927351
# 7 1096.6331584284578
# 8 2980.957987041728
# 9 8103.083927575384
