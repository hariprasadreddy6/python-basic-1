# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print("Hello world!")
print("Namaskar from India")
# Out:
# Hello world!
# Namaskar from India

# %%
print("padhAI")
print("padh"+"AI")
# Out:
# padhAI
# padhAI

# %%
print("1729")
# Out:
# 1729

# %%
print(1000+729)       #Check this with Ramanujan's entry
# Out:
# 1729

# %%
print(55/34)       #golden ratio
# Out:
# 1.6176470588235294

# %%
print(1.681)
# Out:
# 1.681

# %%
print(True)
# Out:
# True

# %%
print(False)
# Out:
# False

# %%
print(True or False)
# Out:
# True

# %%
print(True and False )
# Out:
# False
