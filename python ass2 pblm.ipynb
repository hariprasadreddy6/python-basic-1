# %%
def input_single_float(prompt):
    ret = float(input(prompt))
    return ret

# %%
weight = input_single_float("Enter your weight in kgs ")
height_unit = input(' what is your preferred unit of height "F" of feet and "M" for meter')

if height_unit == "F":
    feet =input_single_integer("please enter both feet and inches. Now enter feet")
    inches =input_single_integer("Now enter inches")
    meters = (feet + inches/12) * 0.3048
else:
    meters = input_single_float ("please enter your height in meters ")

height = meters

bmi = weight / height**2

print("Your BMI is ",bmi)
# Out:
# Enter your weight in kgs 72
#  what is your preferred unit of height "F" of feet and "M" for meterM
# please enter your height in meters 1.82
# Your BMI is  21.736505252988767

# %%
weight = input_single_float("Enter your weight in kgs ")
height_unit = input(' what is your preferred unit of height "F" of feet and "M" for meter')

if height_unit == "F":
    feet =input_single_integer("please enter both feet and inches. Now enter feet")
    inches =input_single_integer("Now enter inches")
    meters = (feet + inches/12) * 0.3048
else:
    meters = input_single_float ("please enter your height in meters ")

height = meters

bmi = weight / height**2

print("Your BMI is ",bmi)

if bmi < 18.5:
    print("You are UNDERWEIGHT.Please consult doctor")
elif bmi < 25:
    print("You are NORMAL. Great going.")
elif bmi < 30:
    print("You are OVERWEIGHT.Watch out.")
else:
    print("You are VERY OVERWEIGHT.Please consult doctor")         #give the different number it will show which statement is correct!
# Out:
# Enter your weight in kgs 85
#  what is your preferred unit of height "F" of feet and "M" for meterM
# please enter your height in meters 1.55
# Your BMI is  35.37981269510926
# You are VERY OVERWEIGHT.Please consult doctor

# %%
def compute_sum_epsilon(x, epsilon):
    sum = 1
    var = epsilon
    i = 1
    while var >= epsilon:
        var = compute_ratio(x, i)
        sum += var
        i += 1
    return sum

# %%
print(compute_sum_epsilon(2, 0.01))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f1a17c64cfb0> in <module>()
# ----> 1 print(compute_sum_epsilon(2, 0.01))
#
# <ipython-input-13-e8b768bc613d> in compute_sum_epsilon(x, epsilon)
#       4     i = 1
#       5     while var >= epsilon:
# ----> 6         var = compute_ratio(x, i)
#       7         sum += var
#       8         i += 1
#
# NameError: name 'compute_ratio' is not defined
